# %%
your_name = 'yunwei'

# %%
import cpuinfo
import dataclasses
import numpy
import platform
import primme
import psutil
import qutip
import sys
import scipy
import scqubits
import time
import timeit
import tqdm

from threadpoolctl import threadpool_info, threadpool_limits

scqubits.settings.PROGRESSBAR_DISABLED = True

def make_numcpus_list():
    all_cpus = qutip.utilities.available_cpu_count()
    if all_cpus == 1:
        return [1]
    if all_cpus == 2:
        return [1, 2]
    if all_cpus <= 4:
        return [1, 2, 4]
    return numpy.linspace(1, all_cpus - 2, 4, dtype=int).tolist()



BM_ITEMS = [
    "test_id",
    "matmode",
    "solver",
    "num_cpus",
    "num_threads",
    "which",
    "sigma",
    "ncv",
    "check_finite",
    "other",
    "time"
]


SOLVERS = {
    "scipy_eigsh": scipy.sparse.linalg.eigsh,
    "primme_eigsh": primme.eigsh
}


TEST_CONFIG_SPARSE = {
    "ZeroPi": {
        "matmode": "sparse",
        "solver":   ["scipy_eigsh", "primme_eigsh"],
        "num_cpus": [1], # ***********************  do sequential testing for now, no multiprocessing on scqubits side
        "num_threads": make_numcpus_list(),
        "which":  ['SA', 'SM', 'LA', 'LM'],
        "ncv": [None, "plus5", "plus10"],
        "evals_count": [6, 10, 20]
    },
    "Cos2PhiQubit": {
        "matmode": "sparse",
        "solver": ["scipy_eigsh", "primme_eigsh"],
        "num_cpus": [1], # *********************** do sequential testing for now, no multiprocessing on scqubits side
        "num_threads": make_numcpus_list(),
        "which":  ['SA', 'SM', 'LA', 'LM'],
        "ncv": [None, "plus5", "plus10"],
        "evals_count": [6, 10, 20]
    },
    # Dropping FullZeroPi for now, takes a long time. Will have to think about reducing overall benchmarks runtime to be an acceptable ask.
    #
    # "FullZeroPi": {
    #     "matmode": "sparse",
    #     "solver": ["scipy_eigsh", "primme_eigsh"],
    #     "num_cpus": [1], # ***********************make_numcpus_list(),
    #     "num_threads": make_numcpus_list(),
    #     "which": ['SA', 'SM', 'LA', 'LM'],
    #     "ncv": [None, "plus5", "plus10"],
    #     "evals_count": [6, 10, 20]
    # }
}

fluxvals = numpy.linspace(0, 0.5, 2)   # 12)



PAYLOAD = {}



@dataclasses.dataclass()
class BenchmarkData:
    test_id: str
    num_cpus: int
    num_threads: int
    which: str
    sigma: str
    ncv: int
    k: int
    eval_0: float
    time: float




def acquire_metadata() -> None:
    global PAYLOAD
    cpu = cpuinfo.get_cpu_info()
    PAYLOAD["platform"] = platform.platform()
    PAYLOAD["machine"] = platform.machine()
    if "M1" in cpu['brand_raw']:
        PAYLOAD["cpuinfo"] = f"{cpu['brand_raw']}"
    else:
        PAYLOAD["cpuinfo"] = f"{cpu['brand_raw']} {cpu['hz_advertised_friendly']}, act. {cpu['hz_actual_friendly']}"
    PAYLOAD["python_version"] = "%d.%d.%d" % sys.version_info[0:3]
    PAYLOAD["cpu_count"] = "%s" % qutip.utilities.available_cpu_count()
    PAYLOAD["cpu_load_percent"] = psutil.cpu_percent(4)
    PAYLOAD["ram_load_percent"] = psutil.virtual_memory()[2]
    PAYLOAD["ram_load_gb"] = psutil.virtual_memory()[3]/1000000000
    PAYLOAD["python_compiler"] = platform.python_compiler()
    PAYLOAD["scqubits_version"] = scqubits.version.version
    PAYLOAD["numpy_version"] = numpy.version.version
    PAYLOAD["qutip_version"] = qutip.__version__
    try:
        import Cython
        cython_ver = Cython.__version__
    except ImportError:
        cython_ver = 'None'
    PAYLOAD["cython_version"] = cython_ver

    thp_info = threadpool_info()
    for idx, infodict in enumerate(thp_info):
        PAYLOAD[f"threadpool.{idx}.user_api"] = thp_info[idx]['user_api']
        PAYLOAD[f"threadpool.{idx}.internal_api"] = thp_info[idx]['internal_api']
        PAYLOAD[f"threadpool.{idx}.prefix"] = thp_info[idx]['prefix']
        PAYLOAD[f"threadpool.{idx}.version"] = thp_info[idx]['version']
        PAYLOAD[f"threadpool.{idx}.threading_layer"] = thp_info[idx].get('threading_layer')
        PAYLOAD[f"threadpool.{idx}.num_threads"] = thp_info[idx]['num_threads']

    PAYLOAD["blas"] = "%s" % qutip.utilities._blas_info()
    PAYLOAD["openmp"] =  "%s" % str(qutip.settings.has_openmp)
    PAYLOAD["intel_mkl_ext"] = "%s" % str(qutip.settings.has_mkl)

    from numpy.core._multiarray_umath import (__cpu_features__, __cpu_baseline__, __cpu_dispatch__)
    for name, info_dict in numpy.__config__.__dict__.items():
        if name[0] == "_" or type(info_dict) is not type({}): continue
        if not info_dict:
            continue
        for k,v in info_dict.items():
            if "_dir" in k:
                continue
            v = str(v)
            if k == "sources" and len(v) > 200:
                v = v[:60] + " ...\n... " + v[-60:]
            PAYLOAD[f"numpy.{name}.{k}"] = v

    features_found, features_not_found = [], []
    for feature in __cpu_dispatch__:
        if __cpu_features__[feature]:
            features_found.append(feature)
        else:
            features_not_found.append(feature)
    PAYLOAD[f"numpy.simdext.baseline"] = ','.join(__cpu_baseline__)
    PAYLOAD[f"numpy.simdext.found"] = ','.join(features_found)
    PAYLOAD[f"numpy.simdext.notfound"] = ','.join(features_not_found)

# %%
SPARSE_BENCHMARKS = []  # List of BenchmarkData instances


def timeit_and_returnval(func, *args, number=1, **kwargs):
    """Used to get return value from benchmarked function back."""
    output_container = []
    def wrapper():
        output_container.append(func(*args, **kwargs))
    timer = timeit.Timer(wrapper)
    delta = timer.timeit(number)
    return delta, output_container.pop()


def sparse_qubit_benchmarks(verbose=True):
    total_count = sum([len(qbt_dict["solver"]) * len(qbt_dict["num_cpus"]) * len(qbt_dict["num_threads"]) * len(qbt_dict["which"]) * len(qbt_dict["evals_count"])  * len(qbt_dict["ncv"]) for qbt, qbt_dict in TEST_CONFIG_SPARSE.items()])

    with tqdm.notebook.tqdm(total=total_count) as pbar:
        for qubit_name in TEST_CONFIG_SPARSE.keys():
            qbt_class = getattr(scqubits, qubit_name)
            qbt = qbt_class.create()

            bm_idx = 0

            for solver_name in TEST_CONFIG_SPARSE[qubit_name]["solver"]:
                solver = SOLVERS[solver_name]
                for ncpu in TEST_CONFIG_SPARSE[qubit_name]["num_cpus"]:
                    for nthreads in TEST_CONFIG_SPARSE[qubit_name]["num_threads"]:
                        with threadpool_limits(limits=nthreads, user_api='blas'):
                            for which in TEST_CONFIG_SPARSE[qubit_name]["which"]:
                                for k in TEST_CONFIG_SPARSE[qubit_name]["evals_count"]:
                                    for ncv in TEST_CONFIG_SPARSE[qubit_name]["ncv"]:

                                        if ncv == "plus5":
                                            ncv = max(2*k + 1, 20) + 5
                                        elif ncv == "plus10":
                                            ncv = max(2*k + 1, 20) + 10

                                        if which in ["LA", "LM"]:
                                            if "primme" in solver_name:
                                                which = "S" + which[1]
                                            sigma = 0.0
                                        else:
                                            sigma = None

                                        def custom_esys(matrix, *args, **kwargs):
                                            evals, evecs = solver(
                                                matrix, 
                                                k=k,
                                                which=which,
                                                sigma=sigma,
                                                ncv=ncv
                                            )
                                            return evals, evecs

                                        qbt.esys_method = custom_esys
                                        
                                        try:
                                            time_needed, spec = timeit_and_returnval(qbt.get_spectrum_vs_paramvals, "flux", fluxvals, get_eigenstates=True, num_cpus=ncpu)
                                        except Exception as exc:
                                            time_needed = -1
    
                                        
                                        
                                        bm = BenchmarkData(
                                            test_id=f"{qubit_name} {solver_name} {bm_idx}",
                                            num_cpus=ncpu,
                                            num_threads=nthreads,
                                            which=which,
                                            sigma=sigma,
                                            ncv=ncv,
                                            k=k,
                                            eval_0=spec.energy_table[0][0],
                                            time=time_needed
                                        )
                                        if verbose:
                                            print(bm)
                                            
                                        SPARSE_BENCHMARKS.append(bm)
                                        bm_idx += 1
                                        pbar.update(1)

# %%
acquire_metadata()
sparse_qubit_benchmarks()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=576.0), HTML(value='')))
# HBox(children=(VBox(children=(HBox(children=(Label(value='EJ [GHz]'), FloatText(value=10.0, layout=Layout(widt…
# Output()
# BenchmarkData(test_id='ZeroPi scipy_eigsh 0', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3537833230002434)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 1', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.2983918719983194)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 2', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.2772790320013883)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 3', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.2794534819986438)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 4', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.2825891770044109)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 5', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3621334780036705)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 6', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.4914580680051586)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 7', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.4290515870015952)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 8', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.614350044997991)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 9', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3879892240001936)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 10', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.404090828000335)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 11', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.363175308004429)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 12', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3694912899954943)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 13', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3782906500055105)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 14', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3702341030002572)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 15', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.342207016001339)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 16', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3592898580027395)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 17', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3551318850004463)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 18', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3708350829983829)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 19', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.3611918079986935)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 20', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.3374344749972806)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 21', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.3402344530040864)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 22', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3780536240010406)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 23', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.370822313001554)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 24', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.352402816999529)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 25', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.339068989000225)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 26', num_cpus=1, num_threads=1, which='LA', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.3533342619994073)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 27', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3726595100015402)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 28', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.384611945002689)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 29', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.364206653997826)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 30', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.3540046500056633)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 31', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3731214509971323)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 32', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.3749628300065524)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 33', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.3718260720052058)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 34', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.3767498269953649)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 35', num_cpus=1, num_threads=1, which='LM', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.336220447999949)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 36', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.363810997994733)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 37', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3870458719975431)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 38', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3677500470002997)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 39', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.373573603996192)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 40', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3693604599975515)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 41', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3706417490029708)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 42', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3509346780047053)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 43', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3476719339960255)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 44', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3864285310046398)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 45', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3698933349951403)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 46', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3671130910006468)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 47', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3724264150005183)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 48', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3716432349974639)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 49', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3724259480004548)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 50', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.369991088999086)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 51', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.6255765649984824)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 52', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3714290030038683)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 53', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3850096829992253)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 54', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.4020853799956967)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 55', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.366690169001231)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 56', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.3733927619978203)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 57', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.3704222320011468)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 58', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3754717920019175)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 59', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.3668293779992382)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 60', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.4020580850046827)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 61', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.397515555996506)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 62', num_cpus=1, num_threads=2, which='LA', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.3628471219999483)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 63', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3854186390017276)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 64', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.4129733959998703)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 65', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.5943915149982786)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 66', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.503710648001288)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 67', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3739917440034333)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 68', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.3650746700004674)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 69', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.412974934995873)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 70', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.3675095869984943)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 71', num_cpus=1, num_threads=2, which='LM', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.3670669290004298)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 72', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.364237588000833)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 73', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3710561010011588)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 74', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3668544460015255)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 75', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3590456720048678)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 76', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3676093719986966)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 77', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3659877809986938)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 78', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3708662470016861)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 79', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3659898810001323)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 80', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3781838150025578)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 81', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3701783419965068)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 82', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3610569869997562)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 83', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3647147320007207)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 84', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3382172159981565)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 85', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3850038680029684)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 86', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3644301399981487)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 87', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3704720550013008)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 88', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.382880548000685)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 89', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3438036400038982)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 90', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3393993040008354)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 91', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.363945857003273)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 92', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.3608065860025818)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 93', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.3449261290006689)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 94', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3776553190036793)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 95', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.3916191220050678)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 96', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.3911022730026161)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 97', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.350213331003033)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 98', num_cpus=1, num_threads=4, which='LA', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.3389716969977599)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 99', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3409184539996204)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 100', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.3560609850028413)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 101', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.3698335829976713)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 102', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.3469906699974672)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 103', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.3816741049959091)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 104', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.3645406720024766)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 105', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.393347042001551)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 106', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.3503289069994935)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 107', num_cpus=1, num_threads=4, which='LM', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.3384726500007673)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 108', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3368010620033601)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 109', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3650438650001888)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 110', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3688514050008962)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 111', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3349769589985954)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 112', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3363975019965437)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 113', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3358331030030968)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 114', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.358915374999924)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 115', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3566701559975627)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 116', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3333572259944049)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 117', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3435445649956819)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 118', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.339618762001919)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 119', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3570251779965474)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 120', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3597551209968515)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 121', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3360101419966668)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 122', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3381377039986546)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 123', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3424289190006675)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 124', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.349732918999507)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 125', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3811050799995428)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 126', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3575307759965654)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 127', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.4836663179958123)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 128', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.5021483809978236)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 129', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.5124200569989625)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 130', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.4290163990008296)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 131', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.4707271040024352)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 132', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.5168568840017542)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 133', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.5346861329962849)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 134', num_cpus=1, num_threads=6, which='LA', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.4827303690035478)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 135', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.5939997599998605)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 136', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=25, k=6, eval_0=16.993839848490385, time=1.6436046439994243)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 137', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=30, k=6, eval_0=16.993839848490385, time=1.5304169890005141)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 138', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=None, k=10, eval_0=16.993839848490385, time=1.42413345699606)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 139', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=26, k=10, eval_0=16.993839848490385, time=1.5059690540001611)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 140', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=31, k=10, eval_0=16.993839848490385, time=1.4822888990020147)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 141', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=None, k=20, eval_0=16.993839848490385, time=1.5626410400000168)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 142', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=46, k=20, eval_0=16.993839848490385, time=1.4852409930026624)
# BenchmarkData(test_id='ZeroPi scipy_eigsh 143', num_cpus=1, num_threads=6, which='LM', sigma=0.0, ncv=51, k=20, eval_0=16.993839848490385, time=1.469002202997217)
# BenchmarkData(test_id='ZeroPi primme_eigsh 144', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.4963513539987616)
# BenchmarkData(test_id='ZeroPi primme_eigsh 145', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.5584766219981248)
# BenchmarkData(test_id='ZeroPi primme_eigsh 146', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.4977299909951398)
# BenchmarkData(test_id='ZeroPi primme_eigsh 147', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.4659089260021574)
# BenchmarkData(test_id='ZeroPi primme_eigsh 148', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.4916345450037625)
# BenchmarkData(test_id='ZeroPi primme_eigsh 149', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.547387541999342)
# BenchmarkData(test_id='ZeroPi primme_eigsh 150', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.4969713130049058)
# BenchmarkData(test_id='ZeroPi primme_eigsh 151', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.5081990909966407)
# BenchmarkData(test_id='ZeroPi primme_eigsh 152', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.4683570659981342)
# BenchmarkData(test_id='ZeroPi primme_eigsh 153', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.4114488329942105)
# BenchmarkData(test_id='ZeroPi primme_eigsh 154', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.345630046002043)
# BenchmarkData(test_id='ZeroPi primme_eigsh 155', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3307356759978575)
# BenchmarkData(test_id='ZeroPi primme_eigsh 156', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3377505469979951)
# BenchmarkData(test_id='ZeroPi primme_eigsh 157', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3382049169958918)
# BenchmarkData(test_id='ZeroPi primme_eigsh 158', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3346970009952202)
# BenchmarkData(test_id='ZeroPi primme_eigsh 159', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3431179870021879)
# BenchmarkData(test_id='ZeroPi primme_eigsh 160', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3614719460019842)
# BenchmarkData(test_id='ZeroPi primme_eigsh 161', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3779088329974911)
# BenchmarkData(test_id='ZeroPi primme_eigsh 162', num_cpus=1, num_threads=1, which='SA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3400384320048033)
# BenchmarkData(test_id='ZeroPi primme_eigsh 163', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3386459070025012)
# BenchmarkData(test_id='ZeroPi primme_eigsh 164', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.33435685600125)
# BenchmarkData(test_id='ZeroPi primme_eigsh 165', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.334147938003298)
# BenchmarkData(test_id='ZeroPi primme_eigsh 166', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3463448879992939)
# BenchmarkData(test_id='ZeroPi primme_eigsh 167', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.4156817869952647)
# BenchmarkData(test_id='ZeroPi primme_eigsh 168', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.4086705240042647)
# BenchmarkData(test_id='ZeroPi primme_eigsh 169', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3772010800021235)
# BenchmarkData(test_id='ZeroPi primme_eigsh 170', num_cpus=1, num_threads=1, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3709845449993736)
# BenchmarkData(test_id='ZeroPi primme_eigsh 171', num_cpus=1, num_threads=1, which='SM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.354666225000983)
# BenchmarkData(test_id='ZeroPi primme_eigsh 172', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3303118949988857)
# BenchmarkData(test_id='ZeroPi primme_eigsh 173', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.493711021998024)
# BenchmarkData(test_id='ZeroPi primme_eigsh 174', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.5740114379950683)
# BenchmarkData(test_id='ZeroPi primme_eigsh 175', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.5319548879997456)
# BenchmarkData(test_id='ZeroPi primme_eigsh 176', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3625998049974442)
# BenchmarkData(test_id='ZeroPi primme_eigsh 177', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3371788270014804)
# BenchmarkData(test_id='ZeroPi primme_eigsh 178', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3694623990013497)
# BenchmarkData(test_id='ZeroPi primme_eigsh 179', num_cpus=1, num_threads=1, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3886900049983524)
# BenchmarkData(test_id='ZeroPi primme_eigsh 180', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3702164279966382)
# BenchmarkData(test_id='ZeroPi primme_eigsh 181', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3791349769962835)
# BenchmarkData(test_id='ZeroPi primme_eigsh 182', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3361095649961499)
# BenchmarkData(test_id='ZeroPi primme_eigsh 183', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3428278909996152)
# BenchmarkData(test_id='ZeroPi primme_eigsh 184', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.338417147002474)
# BenchmarkData(test_id='ZeroPi primme_eigsh 185', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.339590491996205)
# BenchmarkData(test_id='ZeroPi primme_eigsh 186', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3597413930037874)
# BenchmarkData(test_id='ZeroPi primme_eigsh 187', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3610187330050394)
# BenchmarkData(test_id='ZeroPi primme_eigsh 188', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3634203060064465)
# BenchmarkData(test_id='ZeroPi primme_eigsh 189', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3664148270036094)
# BenchmarkData(test_id='ZeroPi primme_eigsh 190', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.379647626003134)
# BenchmarkData(test_id='ZeroPi primme_eigsh 191', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.35700849800196)
# BenchmarkData(test_id='ZeroPi primme_eigsh 192', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3448446469992632)
# BenchmarkData(test_id='ZeroPi primme_eigsh 193', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3331379299997934)
# BenchmarkData(test_id='ZeroPi primme_eigsh 194', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3358650329973898)
# BenchmarkData(test_id='ZeroPi primme_eigsh 195', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3534235269980854)
# BenchmarkData(test_id='ZeroPi primme_eigsh 196', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3759397419999004)
# BenchmarkData(test_id='ZeroPi primme_eigsh 197', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3342269220011076)
# BenchmarkData(test_id='ZeroPi primme_eigsh 198', num_cpus=1, num_threads=2, which='SA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3396929640002782)
# BenchmarkData(test_id='ZeroPi primme_eigsh 199', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3424370540014934)
# BenchmarkData(test_id='ZeroPi primme_eigsh 200', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3351122380045126)
# BenchmarkData(test_id='ZeroPi primme_eigsh 201', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.347334009995393)
# BenchmarkData(test_id='ZeroPi primme_eigsh 202', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3680309310002485)
# BenchmarkData(test_id='ZeroPi primme_eigsh 203', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3554324900032952)
# BenchmarkData(test_id='ZeroPi primme_eigsh 204', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3348185059949174)
# BenchmarkData(test_id='ZeroPi primme_eigsh 205', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3439667909988202)
# BenchmarkData(test_id='ZeroPi primme_eigsh 206', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3411903499945765)
# BenchmarkData(test_id='ZeroPi primme_eigsh 207', num_cpus=1, num_threads=2, which='SM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3532222549983999)
# BenchmarkData(test_id='ZeroPi primme_eigsh 208', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3847137379998458)
# BenchmarkData(test_id='ZeroPi primme_eigsh 209', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.345909584997571)
# BenchmarkData(test_id='ZeroPi primme_eigsh 210', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3327724320042762)
# BenchmarkData(test_id='ZeroPi primme_eigsh 211', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3463351620011963)
# BenchmarkData(test_id='ZeroPi primme_eigsh 212', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3372527480023564)
# BenchmarkData(test_id='ZeroPi primme_eigsh 213', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.343891672004247)
# BenchmarkData(test_id='ZeroPi primme_eigsh 214', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3646833680031705)
# BenchmarkData(test_id='ZeroPi primme_eigsh 215', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3400998239958426)
# BenchmarkData(test_id='ZeroPi primme_eigsh 216', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3319048109988216)
# BenchmarkData(test_id='ZeroPi primme_eigsh 217', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3376411630015355)
# BenchmarkData(test_id='ZeroPi primme_eigsh 218', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3494722389950766)
# BenchmarkData(test_id='ZeroPi primme_eigsh 219', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3677590539955418)
# BenchmarkData(test_id='ZeroPi primme_eigsh 220', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3436859499997809)
# BenchmarkData(test_id='ZeroPi primme_eigsh 221', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3354294590026257)
# BenchmarkData(test_id='ZeroPi primme_eigsh 222', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3404425820044708)
# BenchmarkData(test_id='ZeroPi primme_eigsh 223', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3357963930029655)
# BenchmarkData(test_id='ZeroPi primme_eigsh 224', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3424069290049374)
# BenchmarkData(test_id='ZeroPi primme_eigsh 225', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.365300199999183)
# BenchmarkData(test_id='ZeroPi primme_eigsh 226', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3390159679984208)
# BenchmarkData(test_id='ZeroPi primme_eigsh 227', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.336123763001524)
# BenchmarkData(test_id='ZeroPi primme_eigsh 228', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.333089318999555)
# BenchmarkData(test_id='ZeroPi primme_eigsh 229', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3627325580018805)
# BenchmarkData(test_id='ZeroPi primme_eigsh 230', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.348406397002691)
# BenchmarkData(test_id='ZeroPi primme_eigsh 231', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3340760369974305)
# BenchmarkData(test_id='ZeroPi primme_eigsh 232', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3557644879983854)
# BenchmarkData(test_id='ZeroPi primme_eigsh 233', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3470971810020274)
# BenchmarkData(test_id='ZeroPi primme_eigsh 234', num_cpus=1, num_threads=4, which='SA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3323264880018542)
# BenchmarkData(test_id='ZeroPi primme_eigsh 235', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3622919859990361)
# BenchmarkData(test_id='ZeroPi primme_eigsh 236', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3611939629990957)
# BenchmarkData(test_id='ZeroPi primme_eigsh 237', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3559707349995733)
# BenchmarkData(test_id='ZeroPi primme_eigsh 238', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3622679539985256)
# BenchmarkData(test_id='ZeroPi primme_eigsh 239', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3382930510051665)
# BenchmarkData(test_id='ZeroPi primme_eigsh 240', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3622432839983958)
# BenchmarkData(test_id='ZeroPi primme_eigsh 241', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.373720443007187)
# BenchmarkData(test_id='ZeroPi primme_eigsh 242', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.336280777999491)
# BenchmarkData(test_id='ZeroPi primme_eigsh 243', num_cpus=1, num_threads=4, which='SM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3327044750039931)
# BenchmarkData(test_id='ZeroPi primme_eigsh 244', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3340425379938097)
# BenchmarkData(test_id='ZeroPi primme_eigsh 245', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3356342600018252)
# BenchmarkData(test_id='ZeroPi primme_eigsh 246', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.350927680003224)
# BenchmarkData(test_id='ZeroPi primme_eigsh 247', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3625793179962784)
# BenchmarkData(test_id='ZeroPi primme_eigsh 248', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3459842529991874)
# BenchmarkData(test_id='ZeroPi primme_eigsh 249', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3475137369969161)
# BenchmarkData(test_id='ZeroPi primme_eigsh 250', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3419371330019203)
# BenchmarkData(test_id='ZeroPi primme_eigsh 251', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3799289319940726)
# BenchmarkData(test_id='ZeroPi primme_eigsh 252', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3780086460028542)
# BenchmarkData(test_id='ZeroPi primme_eigsh 253', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3741213219982455)
# BenchmarkData(test_id='ZeroPi primme_eigsh 254', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3306023929981166)
# BenchmarkData(test_id='ZeroPi primme_eigsh 255', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3378317539973068)
# BenchmarkData(test_id='ZeroPi primme_eigsh 256', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3726942330031306)
# BenchmarkData(test_id='ZeroPi primme_eigsh 257', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3565776809991803)
# BenchmarkData(test_id='ZeroPi primme_eigsh 258', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3400111030059634)
# BenchmarkData(test_id='ZeroPi primme_eigsh 259', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3444959850021405)
# BenchmarkData(test_id='ZeroPi primme_eigsh 260', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3320450189930853)
# BenchmarkData(test_id='ZeroPi primme_eigsh 261', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=6, eval_0=16.993839848490385, time=1.3325695730018197)
# BenchmarkData(test_id='ZeroPi primme_eigsh 262', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3594447139985277)
# BenchmarkData(test_id='ZeroPi primme_eigsh 263', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3809308799973223)
# BenchmarkData(test_id='ZeroPi primme_eigsh 264', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3373473089959589)
# BenchmarkData(test_id='ZeroPi primme_eigsh 265', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3297839010047028)
# BenchmarkData(test_id='ZeroPi primme_eigsh 266', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3349942749991897)
# BenchmarkData(test_id='ZeroPi primme_eigsh 267', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.344678407003812)
# BenchmarkData(test_id='ZeroPi primme_eigsh 268', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.369317681004759)
# BenchmarkData(test_id='ZeroPi primme_eigsh 269', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3300062179987435)
# BenchmarkData(test_id='ZeroPi primme_eigsh 270', num_cpus=1, num_threads=6, which='SA', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3366206439968664)
# BenchmarkData(test_id='ZeroPi primme_eigsh 271', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3648081430001184)
# BenchmarkData(test_id='ZeroPi primme_eigsh 272', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3879257310036337)
# BenchmarkData(test_id='ZeroPi primme_eigsh 273', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3804249520035228)
# BenchmarkData(test_id='ZeroPi primme_eigsh 274', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3468687369968393)
# BenchmarkData(test_id='ZeroPi primme_eigsh 275', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.3346603629979654)
# BenchmarkData(test_id='ZeroPi primme_eigsh 276', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.3353942059984547)
# BenchmarkData(test_id='ZeroPi primme_eigsh 277', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3885482600016985)
# BenchmarkData(test_id='ZeroPi primme_eigsh 278', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3803491789949476)
# BenchmarkData(test_id='ZeroPi primme_eigsh 279', num_cpus=1, num_threads=6, which='SM', sigma=0.0, ncv=None, k=6, eval_0=16.993839848490385, time=1.3835416330039152)
# BenchmarkData(test_id='ZeroPi primme_eigsh 280', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=25, k=6, eval_0=16.993839848490385, time=1.3445167039972148)
# BenchmarkData(test_id='ZeroPi primme_eigsh 281', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=30, k=6, eval_0=16.993839848490385, time=1.3395301630007452)
# BenchmarkData(test_id='ZeroPi primme_eigsh 282', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=10, eval_0=16.993839848490385, time=1.3454171789999236)
# BenchmarkData(test_id='ZeroPi primme_eigsh 283', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=26, k=10, eval_0=16.993839848490385, time=1.3608054550059023)
# BenchmarkData(test_id='ZeroPi primme_eigsh 284', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=31, k=10, eval_0=16.993839848490385, time=1.352082232995599)
# BenchmarkData(test_id='ZeroPi primme_eigsh 285', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=20, eval_0=16.993839848490385, time=1.343646291999903)
# BenchmarkData(test_id='ZeroPi primme_eigsh 286', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=46, k=20, eval_0=16.993839848490385, time=1.3439251750023686)
# BenchmarkData(test_id='ZeroPi primme_eigsh 287', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=51, k=20, eval_0=16.993839848490385, time=1.3435229759998037)
# HBox(children=(VBox(children=(HBox(children=(Label(value='EJ [GHz]'), FloatText(value=15.0, layout=Layout(widt…
# Output()
# ...
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 196', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6019071339978836)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 197', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6036291959972004)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 198', num_cpus=1, num_threads=2, which='SA', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6035553830006393)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 199', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6329937589980545)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 200', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6108208299992839)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 201', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.6039572699955897)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 202', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6180582789966138)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 203', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6238309960026527)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 204', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6206753799997387)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 205', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6092081989991129)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 206', num_cpus=1, num_threads=2, which='SA', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6007262680068379)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 207', num_cpus=1, num_threads=2, which='SM', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6069684679969214)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 208', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.61259475100087)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 209', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6029741439997451)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 210', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.6041890630003763)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 211', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.7549837400001707)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 212', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6060649610008113)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 213', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6023307229988859)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 214', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6150755130001926)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 215', num_cpus=1, num_threads=2, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6418386099976487)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 216', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=6, eval_0=12.477406428829164, time=0.6386431030041422)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 217', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6132029090003925)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 218', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.599349884003459)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 219', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.608760600000096)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 220', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6053696510061854)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 221', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6118101530009881)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 222', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.605589760998555)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 223', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.647663609997835)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 224', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6499316439949325)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 225', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=6, eval_0=12.477406428829164, time=0.6193943449979997)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 226', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6186362420048681)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 227', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6219858420008677)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 228', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.616479894000804)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 229', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6031336209998699)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 230', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6013787609990686)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 231', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.623516669998935)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 232', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6020526610009256)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 233', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6059984140010783)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 234', num_cpus=1, num_threads=4, which='SA', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6023402479986544)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 235', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6081784120033262)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 236', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6280039429984754)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 237', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.62456894099887)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 238', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6122718360056751)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 239', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6242974620035966)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 240', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6220002390036825)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 241', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6195318379977834)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 242', num_cpus=1, num_threads=4, which='SA', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6015462740033399)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 243', num_cpus=1, num_threads=4, which='SM', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6084704040040378)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 244', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6054785619999166)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 245', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.604831919001299)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 246', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.6030239969986724)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 247', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6057165739985066)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 248', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6260760899967863)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 249', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6040794530053972)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 250', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6069496439959039)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 251', num_cpus=1, num_threads=4, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6253448510033195)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 252', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=6, eval_0=12.477406428829164, time=0.6164694229955785)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 253', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.612016353996296)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 254', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6016413480028859)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 255', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.6022801930012065)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 256', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.60202482999739)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 257', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6076146690029418)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 258', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6047694680019049)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 259', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6005227239947999)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 260', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6037698130021454)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 261', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=6, eval_0=12.477406428829164, time=0.6077543550054543)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 262', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.603016013999877)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 263', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6040748140003416)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 264', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.6258809259961708)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 265', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6151764339956571)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 266', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6156616449952708)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 267', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6260384790002718)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 268', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6034536410006694)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 269', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6055401319972589)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 270', num_cpus=1, num_threads=6, which='SA', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6077733849961078)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 271', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.6063540290051606)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 272', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6097288230012055)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 273', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.605239085998619)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 274', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.6014646890034783)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 275', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6072553889971459)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 276', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6042607170020347)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 277', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6102786359988386)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 278', num_cpus=1, num_threads=6, which='SA', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6047289089983678)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 279', num_cpus=1, num_threads=6, which='SM', sigma=0.0, ncv=None, k=6, eval_0=12.477406428829164, time=0.6001859789976152)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 280', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=25, k=6, eval_0=12.477406428829164, time=0.617196535000403)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 281', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=30, k=6, eval_0=12.477406428829164, time=0.6421786520004389)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 282', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=10, eval_0=12.477406428829164, time=0.632036770999548)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 283', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=26, k=10, eval_0=12.477406428829164, time=0.613263632003509)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 284', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=31, k=10, eval_0=12.477406428829164, time=0.6011411159997806)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 285', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=None, k=20, eval_0=12.477406428829164, time=0.6070745040051406)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 286', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=46, k=20, eval_0=12.477406428829164, time=0.6020869530038908)
# BenchmarkData(test_id='Cos2PhiQubit primme_eigsh 287', num_cpus=1, num_threads=6, which='SM', sigma=None, ncv=51, k=20, eval_0=12.477406428829164, time=0.6050434909993783)

# %%
import pickle
with open(your_name+'_benchmarks_sparse.pkl', 'wb') as f:  # open a file
    pickle.dump(SPARSE_BENCHMARKS, f) # serialize the list

# %%
import pandas
df = pandas.DataFrame(SPARSE_BENCHMARKS)

# %%
for key in PAYLOAD:
#     print(PAYLOAD[key])
    PAYLOAD[key]=[PAYLOAD[key]]

# %%
df_pl=pandas.DataFrame.from_dict(PAYLOAD)
# Repeat DataFrame 'df_b' to match the number of rows in DataFrame 'a'
b_repeated = pandas.concat([df_pl] * len(df), ignore_index=True)

# Concatenate 'a' and the repeated 'b' horizontally
result = pandas.concat([df, b_repeated], axis=1)
result.to_excel(your_name+'.xlsx')
